# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#      brand     model  year  engine_size fuel_type transmission  mileage  price
# 0   Toyota   Corolla  2018          1.8    Petrol    Automatic    45000  15000
# 1    Honda     Civic  2020          2.0    Petrol       Manual    30000  20000
# 2     Ford     Focus  2017          1.5    Diesel       Manual    60000  12000
# 3      BMW  3 Series  2019          2.0    Petrol    Automatic    35000  28000
# 4  Hyundai   Elantra  2021          2.0    Petrol    Automatic    15000  22000
